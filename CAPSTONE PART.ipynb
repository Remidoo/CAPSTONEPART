# %%
# Import libraries
import json
import requests
   
# Defining Binance API URL
key = "https://api.binance.com/api/v3/ticker/price?symbol="
  
# Making list for multiple crypto's
currencies = ["BTCUSDT", "DOGEUSDT", "LTCUSDT", "ETHUSDT", "BNBUSDT", "XRPUSDT", "ADAUSDT", "SOLUSDT", "USDCUSDT", "BUSDUSDT", "DAIUSDT", "DOTUSDT", "DAIUSDT", "TRXUSDT", "LEVERUSDT", "BONDUSDT", "MATICUSDT", "FIDAUSDT", "MITHUSDT", "SHIBUSDT", "BURGERUSDT", "FIROUSDT", "ERNUSDT", "ETCUSDT", "LDOUSDT", "AVAXUSDT", "UNIUSDT", "FTTUSDT", "LINKUSDT", "ETCUSDT", "NEARUSDT", "XLMUSDT", "NEARUSDT", "ATOMUSDT"]
available_currencies = ["BTC", "DOGE", "LTC", "ETH", "BNB", "XRP", "ADA", "SOL", "USDC", "BUSD", "DAI", "DOT", "DAI", "TRX", "LEVER", "BOND", "MATIC", "FIDA", "MITH", "SHIB", "BURGER", "FIRO", "ERN", "ETC", "LDO", "AVAX", "UNI", "FTT", "LINK", "ETC", "NEAR", "XLM", "NEAR", "ATOM"]
j = 0

# running loop to print all crypto prices
for i in currencies:    
    # completing API for request
    url = key+currencies[j] 
    data = requests.get(url)
    data = data.json()
    
    if x in available_currencies:
        currency_index = available_currencies.index(x)
        chosen_crypto = currencies[currency_index]
        print(f"{data['symbol']} price is ${data['price']}")

# %%
#Gets USD value of 321 cryptocurrencies

# Import libraries
import json
import requests
  
x = input('Enter cryptocurrency to convert:')
print(x)
    
# Defining Binance API URL
key = "https://api.binance.com/api/v3/ticker/price?symbol="
  
# Making list for multiple crypto's
currencies = {"BTC":"BTCUSDT",
"ETH":"ETHUSDT",
"USDC":"USDCUSDT",
"BNB":"BNBUSDT",
"BUSD":"BUSDUSDT",
"XRP":"XRPUSDT",
"ADA":"ADAUSDT",
"SOL":"SOLUSDT",
"DOGE":"DOGEUSDT",
"DOT":"DOTUSDT",
"MATIC":"MATICUSDT",
"AVAX":"AVAXUSDT",
"SHIB":"SHIBUSDT",
"TRX":"TRXUSDT",
"UNI":"UNIUSDT",
"LTC":"LTCUSDT",
"FTT":"FTTUSDT",
"LINK":"LINKUSDT",
"ETC":"ETCUSDT",
"NEAR":"NEARUSDT",
"XLM":"XLMUSDT",
"ATOM":"ATOMUSDT",
"XMR":"XMRUSDT",
"ALGO":"ALGOUSDT",
"BCH":"BCHUSDT",
"ICP":"ICPUSDT",
"APE":"APEUSDT",
"VET":"VETUSDT",
"FLOW":"FLOWUSDT",
"MANA":"MANAUSDT",
"SAND":"SANDUSDT",
"XTZ":"XTZUSDT",
"HBAR":"HBARUSDT",
"EGLD":"EGLDUSDT",
"FIL":"FILUSDT",
"AAVE":"AAVEUSDT",
"AXS":"AXSUSDT",
"THETA":"THETAUSDT",
"QNT":"QNTUSDT",
"TUSD":"TUSDUSDT",
"HNT":"HNTUSDT",
"EOS":"EOSUSDT",
"MKR":"MKRUSDT",
"ZEC":"ZECUSDT",
"BLZ":"BLZUSDT",
"CLV":"CLVUSDT",
"FARM":"FARMUSDT",
"PHA":"PHAUSDT",
"HARD":"HARDUSDT",
"AVA":"AVAUSDT",
"BIFI":"BIFIUSDT",
"LIT":"LITUSDT",
"ATA":"ATAUSDT",
"DNT":"DNTUSDT",
"COS":"COSUSDT",
"IRIS":"IRISUSDT",
"FIRO":"FIROUSDT",
"ALPINE":"ALPINEUSDT",
"AGLD":"AGLDUSDT",
"FIO":"FIOUSDT",
"UNFI":"UNFIUSDT",
"CTXC":"CTXCUSDT",
"ERN":"ERNUSDT",
"KP3R":"KP3RUSDT",
"CHESS":"CHESSUSDT",
"RARE":"RAREUSDT",
"ADX":"ADXUSDT",
"DATA":"DATAUSDT",
"WNXM":"WNXMUSDT",
"TORN":"TORNUSDT",
"QUICK":"QUICKUSDT",
"AKRO":"AKROUSDT",
"OM":"OMUSDT",
"VOXEL":"VOXELUSDT",
"FIDA":"FIDAUSDT",
"FRONT":"FRONTUSDT",
"NULS":"NULSUSDT",
"KEY":"KEYUSDT",
"FIS":"FISUSDT",
"BEAM":"BEAMUSDT",
"DREP":"DREPUSDT",
"PSG":"PSGUSDT",
"MDT":"MDTUSDT",
"GTO":"GTOUSDT",
"LAZIO":"LAZIOUSDT",
"HIGH":"HIGHUSDT",
"WTC":"WTCUSDT",
"DF":"DFUSDT",
"AION":"AIONUSDT",
"DOCK":"DOCKUSDT",
"DEXE":"DEXEUSDT",
"DODO":"DODOUSDT",
"SANTOS":"SANTOSUSDT",
"OOKI":"OOKIUSDT",
"LOKA":"LOKAUSDT",
"BAR":"BARUSDT",
"PNT":"PNTUSDT",
"CITY":"CITYUSDT",
"PORTO":"PORTOUSDT",
"VIDT":"VIDTUSDT",
"AUTO":"AUTOUSDT",
"CVP":"CVPUSDT",
"VITE":"VITEUSDT",
"WING":"WINGUSDT",
"DEGO":"DEGOUSDT",
"FOR":"FORUSDT",
"MIR":"MIRUSDT",
"AUCTION":"AUCTIONUSDT",
"NBS":"NBSUSDT",
"PERL":"PERLUSDT",
"TCT":"TCTUSDT",
"ACM":"ACMUSDT",
"ATM":"ATMUSDT",
"ASR":"ASRUSDT",
"QI":"QIUSDT",
"JUV":"JUVUSDT",
"OG":"OGUSDT",
"GNO":"GNOUSDT",
"EPX":"EPXUSDT",
"MULTI":"MULTIUSDT",
"OP":"OPUSDT",
"GBP":"GBPUSDT",
"LEVER":"LEVERUSDT"}
              
if x in list(currencies.keys()):
    # completing API for request
    url = key+currencies[x] 
    data = requests.get(url)
    data = data.json()
    cryptoindex = (list(currencies.keys()).index(x))
    cryptovalues = list(currencies.values())
    name = cryptovalues[cryptoindex]
    print(f"{name.replace('USDT','')} price is ${data['price']}")
else: 
    print(f"I'm sorry, there may be a mistake in your input or we may not have the currency you are trying to convert in our system :(. For more information please call the **#HELP** function")
# Out:
# Enter cryptocurrency to convert: LG
# LG
# I'm sorry, there may be a mistake in your input or we may not have the currency you are trying to convert in our system :(. For more information please call the **#HELP** function

# %%
len(currencies.items())
# Out:
# 321
